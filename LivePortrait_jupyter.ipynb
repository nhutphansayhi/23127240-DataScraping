# %% [markdown]
# <a href="https://colab.research.google.com/github/nhutphansayhi/23127240-DataScraping/blob/master/LivePortrait_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/LivePortrait
# %cd /content/LivePortrait

# !rm -rf /content/LivePortrait/pretrained_weights
# !git clone https://huggingface.co/camenduru/LivePortrait /content/LivePortrait/pretrained_weights

# !pip install tyro==0.8.5 onnxruntime-gpu==1.18.1 onnx==1.16.1 gradio==4.36.1 colorama

# %cd /content/LivePortrait/src/utils/dependencies/insightface/thirdparty/face3d/mesh/cython
# !python setup.py build_ext --inplace

# %%
# %cd /content/LivePortrait
# !python inference.py -s /content/LivePortrait/assets/examples/source/IMG_2072.jpg -d /content/LivePortrait/assets/examples/driving/IMG_3470.MOV
# Out:
# /content/LivePortrait
# [04:00:58] Load appearance_feature_extractor done.   ]8;id=939879;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=276359;file:///content/LivePortrait/src/live_portrait_wrapper.py#30\30]8;;\
# [04:00:59] Load motion_extractor done.               ]8;id=877628;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=132453;file:///content/LivePortrait/src/live_portrait_wrapper.py#33\33]8;;\
#            Load warping_module done.                 ]8;id=168079;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=915085;file:///content/LivePortrait/src/live_portrait_wrapper.py#36\36]8;;\
# [04:01:00] Load spade_generator done.                ]8;id=199080;file:///content/LivePortrait/src/live_portrait_wrapper.py\live_portrait_wrapper.py]8;;\:]8;id=125316;file:///content/LivePortrait/src/live_portrait_wrapper.py#39\39]8;;\
# ...

# %%
# Kiểm tra file trong animations (kết quả ở đây!)
# !ls -la /content/LivePortrait/animations/

# Preview video (nếu có)
from IPython.display import Video
Video('/content/LivePortrait/animations/s7--d7_concat.mp4')

# Download trực tiếp
from google.colab import files
files.download('/content/LivePortrait/animations/s7--d7_concat.mp4')
# Out:
# total 1824
# drwxr-xr-x 2 root root    4096 Jan 30 03:37 .
# drwxr-xr-x 8 root root    4096 Jan 30 03:37 ..
# -rw-r--r-- 1 root root  838444 Jan 30 03:42 s7--d7_concat.mp4
# -rw-r--r-- 1 root root 1017417 Jan 30 03:42 s7--d7.mp4
